# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import stats
import os

# %%
path = 'C:/Users/User/Desktop/Data Science/FCD/individual assay/SSD-generator/chemicals'
os.chdir(path)

# %%
chems = pd.read_excel('AquaticReport.xlsx')
chems.head(3)
# Out:
#    CAS Number                                      Chemical Name  \
# 0       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 1       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 2       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
#
#   Chemical Grade Chemical Analysis Chemical Purity  \
# 0   Not reported        Unmeasured              NR
# 1   Not reported        Unmeasured              NR
# 2   Not reported        Unmeasured              NR
#
#                  Species Scientific Name  Species Common Name Species Group  \
# 0                        Rana temporaria                 Frog    Amphibians
# 1  Pseudacris triseriata ssp. triseriata  Western Chorus Frog    Amphibians
# 2                        Rana temporaria                 Frog    Amphibians
#
#   Organism Lifestage Organism Age  ... BCF 3 Min BCF 3 Max Op BCF 3 Max  \
# 0            Tadpole            8  ...       NaN          NaN       NaN
# 1            Tadpole            7  ...       NaN          NaN       NaN
# 2            Tadpole           16  ...       NaN          NaN       NaN
#
#   BCF 3 Unit         Author Reference Number  \
# 0        NaN  Wohlgemuth,E.             8480
# 1        NaN   Sanders,H.O.             2891
# 2        NaN  Wohlgemuth,E.             8480
#
#                                                Title  \
# 0  Toxicity of Endrin to Some Species of Aquatic ...
# 1  Pesticide Toxicities to Tadpoles of the Wester...
# 2  Toxicity of Endrin to Some Species of Aquatic ...
#
#                                            Source Publication Year  \
# 0  Prirodoved. Pr. Ust. Akad. Ved Brne11(6): 1-38             1977
# 1                                 Copeia2:246-251             1970
# 2  Prirodoved. Pr. Ust. Akad. Ved Brne11(6): 1-38             1977
#
#                     Summary of Additional Parameters
# 0  Purity:   NR - NR | Organism Age:   NR - NR Da...
# 1  Purity:   NR - NR | Organism Age:   NR - NR Da...
# 2  Purity:   NR - NR | Organism Age:   NR - NR Da...
#
# [3 rows x 56 columns]

# %%
chems = chems[chems['Conc 1 Type (Standardized)'] == 'Active ingredient']
chems = chems[chems['Conc 1 Mean (Standardized)'] != 'NR']
chems = chems[chems['Conc 1 Mean Op (Standardized)'].isna()]

days = chems['Observed Duration (Days)'].mode()[0]
chems = chems[chems['Observed Duration (Days)'] == days]
chems.head()
# Out:
#     CAS Number                                      Chemical Name  \
# 16       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 18       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 22       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 23       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
# 28       72208  3,4,5,6,9,9-Hexachloro-1a,2,2a,3,6,6a,7,7a-oct...
#
#                                        Chemical Grade Chemical Analysis  \
# 16                                       Not reported          Measured
# 18  Technical grade, technical product, technical ...          Measured
# 22  Technical grade, technical product, technical ...          Measured
# 23                                       Not reported      Not reported
# 28  Technical grade, technical product, technical ...          Measured
#
#    Chemical Purity                        Species Scientific Name  \
# 16              NR                                Acris crepitans
# 18              98  Lithobates sphenocephalus ssp. sphenocephalus
# 22              98  Lithobates sphenocephalus ssp. sphenocephalus
# 23              99                          Pseudacris triseriata
# 28              98  Lithobates sphenocephalus ssp. sphenocephalus
#
#               Species Common Name Species Group  \
# 16                   Cricket Frog    Amphibians
# 18           Florida Leopard Frog    Amphibians
# 22           Florida Leopard Frog    Amphibians
# 23  Striped, Northern Chorus Frog    Amphibians
# 28           Florida Leopard Frog    Amphibians
#
#                                 Organism Lifestage Organism Age  ...  \
# 16                                           Larva           NR  ...
# 18  Pre-, sub-, semi-, near adult, or peripubertal           NR  ...
# 22                                           Larva           NR  ...
# 23                                         Tadpole           NR  ...
# 28                                           Larva           NR  ...
#
#    BCF 3 Min BCF 3 Max Op BCF 3 Max BCF 3 Unit  \
# 16       NaN          NaN       NaN        NaN
# 18       NaN          NaN       NaN        NaN
# 22       NaN          NaN       NaN        NaN
# 23       NaN          NaN       NaN        NaN
# 28       NaN          NaN       NaN        NaN
#
#                                  Author Reference Number  \
# 16        Hall,R.J., and D.M. Swineford            15747
# 18          Hall,R.J., and D. Swineford             5250
# 22          Hall,R.J., and D. Swineford             5250
# 23  Mayer,F.L.,Jr., and M.R. Ellersieck             6797
# 28          Hall,R.J., and D. Swineford             5250
#
#                                                 Title  \
# 16  Acute Toxicities of Toxaphene and Endrin to La...
# 18  Toxic Effects of Endrin and Toxaphene on the S...
# 22  Toxic Effects of Endrin and Toxaphene on the S...
# 23  Manual of Acute Toxicity: Interpretation and D...
# 28  Toxic Effects of Endrin and Toxaphene on the S...
#
#                                                Source Publication Year  \
# 16                        Toxicol. Lett.8(6): 331-336             1981
# 18                    Environ. Pollut. A.23(1): 53-65             1980
# 22                    Environ. Pollut. A.23(1): 53-65             1980
# 23  USDI Fish and Wildlife Service, Publication No...             1986
# 28                    Environ. Pollut. A.23(1): 53-65             1980
#
#                      Summary of Additional Parameters
# 16  Purity:   NR - NR | Organism Age:   NR - NR No...
# 18  Purity:   NR - NR | Organism Age:   NR - NR No...
# 22  Purity:   NR - NR | Organism Age:   NR - NR No...
# 23  Purity:   NR - NR | Organism Age:   NR - NR No...
# 28  Purity:   NR - NR | Organism Age:   NR - NR No...
#
# [5 rows x 56 columns]

# %%
cols = ['CAS Number','Species Scientific Name', 'Species Common Name', 'Species Group', 'Conc 1 Type (Standardized)', 
       'Conc 1 Mean (Standardized)','Conc 1 Units (Standardized)','Observed Duration (Days)']
chems2 = chems[cols].copy()
chems2
# Out:
#      CAS Number                        Species Scientific Name  \
# 16        72208                                Acris crepitans
# 18        72208  Lithobates sphenocephalus ssp. sphenocephalus
# 22        72208  Lithobates sphenocephalus ssp. sphenocephalus
# 23        72208                          Pseudacris triseriata
# 28        72208  Lithobates sphenocephalus ssp. sphenocephalus
# ..          ...                                            ...
# 676       72208                            Ischnura verticalis
# 680       72208                            Pteronarcella badia
# 682       72208                                     Tipula sp.
# 698       72208                            Hexagenia bilineata
# 699       72208                                     Baetis sp.
#
#                Species Common Name                           Species Group  \
# 16                    Cricket Frog                              Amphibians
# 18            Florida Leopard Frog                              Amphibians
# 22            Florida Leopard Frog                              Amphibians
# 23   Striped, Northern Chorus Frog                              Amphibians
# 28            Florida Leopard Frog                              Amphibians
# ..                             ...                                     ...
# 676                      Damselfly                         Insects/Spiders
# 680                       Stonefly                         Insects/Spiders
# 682                       Cranefly                         Insects/Spiders
# 698                         Mayfly  Insects/Spiders; Standard Test Species
# 699                         Mayfly  Insects/Spiders; Standard Test Species
#
#     Conc 1 Type (Standardized) Conc 1 Mean (Standardized)  \
# 16           Active ingredient                       0.01
# 18           Active ingredient                      0.005
# 22           Active ingredient                      0.006
# 23           Active ingredient                       0.18
# 28           Active ingredient                      0.006
# ..                         ...                        ...
# 676          Active ingredient                     0.0021
# 680          Active ingredient                    0.00054
# 682          Active ingredient                      0.012
# 698          Active ingredient                      0.062
# 699          Active ingredient                     0.0009
#
#     Conc 1 Units (Standardized) Observed Duration (Days)
# 16                      AI mg/L                        4
# 18                      AI mg/L                        4
# 22                      AI mg/L                        4
# 23                      AI mg/L                        4
# 28                      AI mg/L                        4
# ..                          ...                      ...
# 676                     AI mg/L                        4
# 680                     AI mg/L                        4
# 682                     AI mg/L                        4
# 698                     AI mg/L                        4
# 699                     AI mg/L                        4
#
# [122 rows x 8 columns]

# %%
chems2 = chems2[['Species Scientific Name','Conc 1 Mean (Standardized)']]
chems2.loc[:,'Conc 1 Mean (Standardized)'] = chems2.loc[:,'Conc 1 Mean (Standardized)'].astype(float)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py:1047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
chems2 = chems2.groupby('Species Scientific Name', as_index=False)['Conc 1 Mean (Standardized)'].median()
chems2 = chems2.sort_values(by=['Conc 1 Mean (Standardized)'])
chems2.reset_index(drop=True,inplace=True)
chems2.head
# Out:
# <bound method NDFrame.head of                           Species Scientific Name  Conc 1 Mean (Standardized)
# 0                             Claassenia sabulosa                    0.000076
# 1                                Perca flavescens                    0.000150
# 2                            Oncorhynchus clarkii                    0.000152
# 3                         Euphlyctis hexadactylus                    0.000210
# 4                           Micropterus salmoides                    0.000310
# 5                                 Cyprinus carpio                    0.000320
# 6                           Hesperoperla pacifica                    0.000390
# 7                            Oncorhynchus kisutch                    0.000390
# 8                             Ictalurus punctatus                    0.000420
# 9                           Salvelinus fontinalis                    0.000473
# 10                       Oncorhynchus tshawytscha                    0.000530
# 11                            Pteronarcella badia                    0.000540
# 12                            Pimephales promelas                    0.000590
# 13                            Lepomis macrochirus                    0.000605
# 14                            Oncorhynchus mykiss                    0.000750
# 15                                 Ameiurus melas                    0.000790
# 16                            Jordanella floridae                    0.000850
# 17                                     Baetis sp.                    0.000900
# 18                               Gambusia affinis                    0.000925
# 19                              Carassius auratus                    0.000950
# 20                            Poecilia reticulata                    0.001200
# 21                                Barbus dorsalis                    0.001250
# 22                        Pteronarcys californica                    0.001325
# 23                          Caecidotea brevicauda                    0.001500
# 24                       Palaemonetes kadiakensis                    0.001850
# 25                            Ischnura verticalis                    0.002250
# 26                               Rana catesbeiana                    0.002250
# 27                             Gammarus fasciatus                    0.004300
# 28                              Atherix variegata                    0.004600
# 29                                 Tilapia zillii                    0.005175
# 30  Lithobates sphenocephalus ssp. sphenocephalus                    0.006000
# 31                             Gammarus lacustris                    0.007250
# 32                           Ptychocheilus lucius                    0.008000
# 33                      Ptychocheilus oregonensis                    0.008150
# 34                                Acris crepitans                    0.010000
# 35                                Bufo americanus                    0.010000
# 36                                     Tipula sp.                    0.012000
# 37                               Ambystoma opacum                    0.018000
# 38                          Lithobates sylvaticus                    0.034000
# 39                            Ambystoma maculatum                    0.056000
# 40                            Hexagenia bilineata                    0.062000
# 41                   Bufo woodhousei ssp. fowleri                    0.120000
# 42                                Orconectes nais                    0.161600
# 43                          Pseudacris triseriata                    0.180000>

# %%
def preprocess (initial_data):
    
    data = initial_data.copy()
    
    #saving cas
    cas = data.iloc[0,0]
    
    #remove trailing spaces from columns names
    data.columns = pd.Series(data.columns).str.strip().tolist()
    
    #parameter restriction
    data = data[data['Conc 1 Type (Standardized)'] == 'Active ingredient']
    data = data[data['Conc 1 Mean (Standardized)'] != 'NR']
    data = data[data['Conc 1 Units (Standardized)'] == 'AI mg/L']
    data = data[data['Conc 1 Mean Op (Standardized)'].isna()]

    if 'Observed Duration Mean (Days)' in data.columns:
        days = data['Observed Duration Mean (Days)'].mode()[0]
        data = data[data['Observed Duration Mean (Days)'] == days]
    elif 'Observed Duration (Days)' in data.columns:
        days = data['Observed Duration (Days)'].mode()[0]
        data = data[data['Observed Duration (Days)'] == days]
    
    #new df
    cols = ['Species Scientific Name','Conc 1 Mean (Standardized)','Conc 1 Units (Standardized)',
            'Species Group', 'CAS Number'] #'Observed Duration Mean (Days)'
    data = data[cols]
    
    #toxicity str to float
    data = data[['Species Scientific Name','Conc 1 Mean (Standardized)']]
    data.loc[:,'Conc 1 Mean (Standardized)'] = data.loc[:,'Conc 1 Mean (Standardized)'].astype(float)
    
    data = data.groupby('Species Scientific Name', as_index=False)['Conc 1 Mean (Standardized)'].median()
    data = data.sort_values(by=['Conc 1 Mean (Standardized)'])
    data.reset_index(drop=True,inplace=True)
    data['CAS'] = cas
    
    return data

# %%
def plot_SSD (data):
    #finding order of magnitude of min and of max(+1)
    low = data.iloc[:,1].min()
    high = data.iloc[:,1].max()

    xmin, xmax = math.floor(math.log(low, 10))-1, (math.floor(math.log(high, 10)))+2

    plt.figure(figsize=(6,4.5))
    #plotting data points
    a = data.iloc[:,1]

    n_species = data.shape[0]
    perc_val = np.arange(n_species)+1
    percent = [(x-0.5)/data.shape[0] for x in perc_val]

    plt.scatter(a, percent,color='black')


    #plotting fitted lognormal function
    s, loc, scale = stats.lognorm.fit(a)

    x = np.logspace(xmin, xmax, 100)
    y = [stats.lognorm.cdf(x, s, loc=0, scale=scale) for x in x]
    plt.plot(x,y,color='red')

    #adjusting x-axis
    plt.xscale("log")
    plt.gca().set_xlim([math.pow(10,xmin), math.pow(10, xmax)])
    plt.title(str(data.iloc[0,-1]))

    return plt.show()

# %%
def get_HC_AD (data):
    #finding order of magnitude of min and of max(+1)
    low = data.iloc[:,1].min()
    high = data.iloc[:,1].max()

    xmin, xmax = math.floor(math.log(low, 10)), (math.floor(math.log(high, 10)))+1

    #data points
    a = data.iloc[:,1]

    n_species = data.shape[0]
    perc_val = np.arange(n_species)+1
    percent = [(x-0.5)/data.shape[0] for x in perc_val]

    #fitted lognormal function
    s, loc, scale = stats.lognorm.fit(a)

    x = np.logspace(xmin, xmax, 100)
    y = [stats.lognorm.cdf(x, s, loc=0, scale=scale) for x in x]
    
    #HC and AD
    hc5 = stats.lognorm.ppf(0.05, s, loc=0, scale=scale)
    hc50 = scale
    
    adt = stats.anderson(a,dist='logistic')
    if adt[1][2] < 0.752:
        return hc5, hc50, adt[1][2]
    else:
        return 'Error', 'Error', 'Error'

# %%
chems = pd.read_excel('CAquaticReport.xlsx')

new_chems = preprocess (chems)
plot_SSD (new_chems)
get_HC_AD(new_chems)
new_chems
# Out:
#                           Species Scientific Name  Conc 1 Mean (Standardized)  \
# 0                             Claassenia sabulosa                    0.000076
# 1                                Perca flavescens                    0.000150
# 2                            Oncorhynchus clarkii                    0.000152
# 3                         Euphlyctis hexadactylus                    0.000210
# 4                           Micropterus salmoides                    0.000310
# 5                                 Cyprinus carpio                    0.000320
# 6                           Hesperoperla pacifica                    0.000390
# 7                            Oncorhynchus kisutch                    0.000390
# 8                             Ictalurus punctatus                    0.000420
# 9                           Salvelinus fontinalis                    0.000473
# 10                       Oncorhynchus tshawytscha                    0.000530
# 11                            Pteronarcella badia                    0.000540
# 12                            Pimephales promelas                    0.000590
# 13                            Lepomis macrochirus                    0.000605
# 14                            Oncorhynchus mykiss                    0.000750
# 15                                 Ameiurus melas                    0.000790
# 16                            Jordanella floridae                    0.000850
# 17                                     Baetis sp.                    0.000900
# 18                               Gambusia affinis                    0.000925
# 19                              Carassius auratus                    0.000950
# 20                            Poecilia reticulata                    0.001200
# 21                                Barbus dorsalis                    0.001250
# 22                        Pteronarcys californica                    0.001325
# 23                          Caecidotea brevicauda                    0.001500
# 24                       Palaemonetes kadiakensis                    0.001850
# 25                            Ischnura verticalis                    0.002250
# 26                               Rana catesbeiana                    0.002250
# 27                             Gammarus fasciatus                    0.004300
# 28                              Atherix variegata                    0.004600
# 29                                 Tilapia zillii                    0.005175
# 30  Lithobates sphenocephalus ssp. sphenocephalus                    0.006000
# 31                             Gammarus lacustris                    0.007250
# 32                           Ptychocheilus lucius                    0.008000
# 33                      Ptychocheilus oregonensis                    0.008150
# 34                                Acris crepitans                    0.010000
# 35                                Bufo americanus                    0.010000
# 36                                     Tipula sp.                    0.012000
# 37                               Ambystoma opacum                    0.018000
# 38                          Lithobates sylvaticus                    0.034000
# 39                            Ambystoma maculatum                    0.056000
# 40                            Hexagenia bilineata                    0.062000
# 41                   Bufo woodhousei ssp. fowleri                    0.120000
# 42                                Orconectes nais                    0.161600
# 43                          Pseudacris triseriata                    0.180000
#
#       CAS
# 0   72208
# 1   72208
# 2   72208
# 3   72208
# 4   72208
# 5   72208
# 6   72208
# 7   72208
# 8   72208
# 9   72208
# 10  72208
# 11  72208
# 12  72208
# 13  72208
# 14  72208
# 15  72208
# 16  72208
# 17  72208
# 18  72208
# 19  72208
# 20  72208
# 21  72208
# 22  72208
# 23  72208
# 24  72208
# 25  72208
# 26  72208
# 27  72208
# 28  72208
# 29  72208
# 30  72208
# 31  72208
# 32  72208
# 33  72208
# 34  72208
# 35  72208
# 36  72208
# 37  72208
# 38  72208
# 39  72208
# 40  72208
# 41  72208
# 42  72208
# 43  72208

# %%
tox_dict={'CAS':[],'HC5':[]}

for f in os.listdir():
    new_path = path + '/' + str(f)
    
    chems = pd.read_excel(new_path)

    new_chems = preprocess (chems)
    plot_SSD (new_chems)
    hc5, hc50, adf = get_HC_AD(new_chems)
    
    cas = chems.iloc[0,0]
    
    tox_dict['CAS'].append(cas)
    tox_dict['HC5'].append(hc5)

toxicity = pd.DataFrame.from_dict(tox_dict)
toxicity
# Out:
#         CAS       HC5
# 0  38641940  0.164476
# 1     72208  0.000055

# %%
toxicity = pd.DataFrame(columns=['CAS','HC5','HC50','AD(p=0.05)'])

for f in os.listdir():
    new_path = path + '/' + str(f)
    chems = pd.read_excel(new_path)

    new_chems = preprocess (chems)
    plot_SSD (new_chems)
    hc5, hc50, adf = get_HC_AD(new_chems)
    
    cas = str(chems.iloc[0,0])
    
    toxicity.loc[len(toxicity)] = [cas, hc5, hc50, adf]

toxicity
# Out:
#         CAS       HC5       HC50  AD(p=0.05)
# 0  38641940  0.164476  10.418772       0.655
# 1     72208  0.000055   0.001922       0.656

# %%
chems = pd.read_csv("AquaticReport.txt", sep='|')

new_chems = preprocess (chems)
plot_SSD (new_chems)
get_HC_AD(new_chems)
# Out:
# (0.16447568848706903, 10.41877245248028, 0.655)
